# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/SR3
# Out:
# /content/drive/MyDrive/SR3

# %%
# !pip install -r requirement.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 16.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 88.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 27.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.0/254.0 kB 30.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 10.9 MB/s eta 0:00:00
# ...

# %%
pwd
# Out:
# '/content/drive/MyDrive/SR3'

# %%
# !pwd
# Out:
# /content/drive/MyDrive/SR3

# %%
#My code. Don't do this
# !cp -r /content/drive/MyDrive/CTScan_dataset /content/drive/MyDrive/SR3/dataset
# Out:
# ^C

# %%
#Preprocessing. Don't have to do this. Already done
# !python ./data/prepare_data.py --path ./dataset/CTScan_dataset/Data/train/adenocarcinoma --out ./ProcessedDataset/train/adenocarcinoma --size 64,512 --n_worker 3
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/SR3/./data/prepare_data.py", line 9, in <module>
#     from torchvision.transforms import functional as trans_fn
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/__init__.py", line 5, in <module>
#     import torch
#   File "/usr/local/lib/python3.10/dist-packages/torch/__init__.py", line 1504, in <module>
#     from . import masked
#   File "/usr/local/lib/python3.10/dist-packages/torch/masked/__init__.py", line 3, in <module>
#     from ._ops import (
#   File "/usr/local/lib/python3.10/dist-packages/torch/masked/_ops.py", line 11, in <module>
#     from torch._prims_common import corresponding_real_dtype
#   File "/usr/local/lib/python3.10/dist-packages/torch/_prims_common/__init__.py", line 23, in <module>
#     import sympy
#   File "/usr/local/lib/python3.10/dist-packages/sympy/__init__.py", line 74, in <module>
#     from .polys import (Poly, PurePoly, poly_from_expr, parallel_poly_from_expr,
# ...

# %%
#Preprocessing. Don't have to do this. Already done
# !python ./data/prepare_data.py --path ./dataset/CTScan_dataset/Data/train/Normal --out ./ProcessedDataset/train/Normal --size 64,512 --n_worker 3
# !python ./data/prepare_data.py --path ./dataset/CTScan_dataset/Data/train/Large_cell_carcinoma --out ./ProcessedDataset/train/Large_cell_carcinoma --size 64,512 --n_worker 3
# !python ./data/prepare_data.py --path ./dataset/CTScan_dataset/Data/train/Squamous_cell_carcinoma --out ./ProcessedDataset/train/Squamous_cell_carcinoma --size 64,512 --n_worker 3
# !python ./data/prepare_data.py --path ./dataset/CTScan_dataset/Data/test/adenocarcinoma --out ./ProcessedDataset/test/adenocarcinoma --size 64,512 --n_worker 3
# !python ./data/prepare_data.py --path ./dataset/CTScan_dataset/Data/test/Normal --out ./ProcessedDataset/test/Normal --size 64,512 --n_worker 3
# !python ./data/prepare_data.py --path ./dataset/CTScan_dataset/Data/test/Large_cell_carcinoma  --out ./ProcessedDataset/test/Large_cell_carcinoma  --size 64,512 --n_worker 3
# !python ./data/prepare_data.py --path ./dataset/CTScan_dataset/Data/test/Squamous_cell_carcinoma --out ./ProcessedDataset/test/Squamous_cell_carcinoma --size 64,512 --n_worker 3
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# python3: can't open file './data/prepare_data.py': [Errno 107] Transport endpoint is not connected
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# python3: can't open file './data/prepare_data.py': [Errno 107] Transport endpoint is not connected
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# ...

# %%
#Preprocessing. Don't have to do this. Already done
# !python ./data/prepare_data.py --path ./dataset/CTScan_dataset/Data/valid/adenocarcinoma --out ./ProcessedDataset/val/adenocarcinoma --size 64,512 --n_worker 3
# !python ./data/prepare_data.py --path ./dataset/CTScan_dataset/Data/valid/Normal --out ./ProcessedDataset/val/Normal --size 64,512 --n_worker 3
# !python ./data/prepare_data.py --path ./dataset/CTScan_dataset/Data/valid/Large_cell_carcinoma  --out ./ProcessedDataset/val/Large_cell_carcinoma  --size 64,512 --n_worker 3
# !python ./data/prepare_data.py --path ./dataset/CTScan_dataset/Data/valid/Squamous_cell_carcinoma --out ./ProcessedDataset/val/Squamous_cell_carcinoma --size 64,512 --n_worker 3
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# python3: can't open file './data/prepare_data.py': [Errno 107] Transport endpoint is not connected
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# python3: can't open file './data/prepare_data.py': [Errno 107] Transport endpoint is not connected
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# ...

# %%
#Train
# !python sr.py -p train -c /content/drive/MyDrive/SR3/config/sr_sr3_64_512.json
# Out:
# export CUDA_VISIBLE_DEVICES=0
# 23-12-13 18:14:30.340 - INFO:   name: distributed_high_sr_ffhq
#   phase: train
#   gpu_ids: [0]
#   path:[
#     log: experiments/distributed_high_sr_ffhq_231213_181430/logs
#     tb_logger: experiments/distributed_high_sr_ffhq_231213_181430/tb_logger
#     results: experiments/distributed_high_sr_ffhq_231213_181430/results
#     checkpoint: experiments/distributed_high_sr_ffhq_231213_181430/checkpoint
#     resume_state: /content/drive/MyDrive/PretrainModel/I830000_E32
#     experiments_root: experiments/distributed_high_sr_ffhq_231213_181430
#   ]
#   datasets:[
#     train:[
#       name: FFHQ
#       mode: HR
#       dataroot: /content/drive/MyDrive/SR3/ProcessedDataset/train/Normal_64_512
#       datatype: img
#       l_resolution: 64
#       r_resolution: 512
#       batch_size: 2
#       num_workers: 8
#       use_shuffle: True
#       data_len: -1
#     ]
#     val:[
#       name: CelebaHQ
#       mode: LRHR
# ...

# %%
#Validation
# !python sr.py -p val -c /content/drive/MyDrive/SR3/config/sr_sr3_64_512.json
# Out:
# export CUDA_VISIBLE_DEVICES=0
# 23-12-13 18:18:18.677 - INFO:   name: distributed_high_sr_ffhq
#   phase: val
#   gpu_ids: [0]
#   path:[
#     log: experiments/distributed_high_sr_ffhq_231213_181818/logs
#     tb_logger: experiments/distributed_high_sr_ffhq_231213_181818/tb_logger
#     results: experiments/distributed_high_sr_ffhq_231213_181818/results
#     checkpoint: experiments/distributed_high_sr_ffhq_231213_181818/checkpoint
#     resume_state: /content/drive/MyDrive/PretrainModel/I830000_E32
#     experiments_root: experiments/distributed_high_sr_ffhq_231213_181818
#   ]
#   datasets:[
#     train:[
#       name: FFHQ
#       mode: HR
#       dataroot: /content/drive/MyDrive/SR3/ProcessedDataset/train/Normal_64_512
#       datatype: img
#       l_resolution: 64
#       r_resolution: 512
#       batch_size: 2
#       num_workers: 8
#       use_shuffle: True
#       data_len: -1
#     ]
#     val:[
#       name: CelebaHQ
#       mode: LRHR
# ...

# %%
from matplotlib import pyplot as plt
from IPython.display import Image, display
import os

# %%
# Function to display an image
#Failed. Don't do this.
def show_image(image_path):
    img = plt.imread(image_path)
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# Paths of the images
hr_image_path = '{}/{}_{}_hr.png'.format(result_path, current_step, idx)
lr_image_path = '{}/{}_{}_lr.png'.format(result_path, current_step, idx)
sr_image_path = '{}/{}_{}_inf.png'.format(result_path, current_step, idx)

# Display images
show_image(hr_image_path)
show_image(lr_image_path)
show_image(sr_image_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-60e61cd81f9a> in <cell line: 9>()
#       7
#       8 # Paths of the images
# ----> 9 hr_image_path = '{}/{}_{}_hr.png'.format(result_path, current_step, idx)
#      10 lr_image_path = '{}/{}_{}_lr.png'.format(result_path, current_step, idx)
#      11 sr_image_path = '{}/{}_{}_inf.png'.format(result_path, current_step, idx)
#
# NameError: name 'result_path' is not defined
